# %%
from IPython.display import display_html
display_html("""<button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">Toggle Code</button>""", raw=True)
# %pylab
from scipy.io import wavfile
from IPython.display import Audio
# Out:
# <button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">Toggle Code</button>
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# /home/szw73/miniconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['sample']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ## gpyinf->lcxinm

# %% [markdown]
# ### 开赛前匆匆由润迅转手的易康男篮。

# %%
sampleRate, sample = wavfile.read('/home/szw73/wav/cyclegan/5.4/5.4/csnt-131120-0001-131125-gpyinf-0001-GPYINF_0001062_0001544_F_gen.wav')
Audio(data = sample, rate = sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 这一凝聚民心的举措值得肯定。

# %%
sampleRate, sample = wavfile.read('/home/szw73/wav/cyclegan/5.4/5.4/csnt-131120-0001-131125-gpyinf-0001-GPYINF_0002564_0002924_F_gen.wav')
Audio(data = sample, rate = sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 助长党内歪风邪气的滋生和蔓延。

# %%
sampleRate, sample = wavfile.read('/home/szw73/wav/cyclegan/5.4/5.4/csnt-131120-0001-131125-gpyinf-0001-GPYINF_0003016_0003422_F_gen.wav')
Audio(data = sample, rate = sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## lcxinm->gpyinf

# %%
sampleRate, sample = wavfile.read('/home/szw73/wav/cyclegan/5.4/5.4/csnt-131120-0001-131125-lcxinm-0001-LCXINM_0001024_0001480_M_gen.wav')
Audio(data = sample, rate = sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sampleRate, sample = wavfile.read('/home/szw73/wav/cyclegan/5.4/5.4/csnt-131120-0001-131125-lcxinm-0001-LCXINM_0002308_0002660_M_gen.wav')
Audio(data = sample, rate = sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sampleRate, sample = wavfile.read('/home/szw73/wav/cyclegan/5.4/5.4/csnt-131120-0001-131125-lcxinm-0001-LCXINM_0002901_0003292_M_gen.wav')
Audio(data = sample, rate = sampleRate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
